# %%
import pandas as pd
import json

# open JSON
with open("steam_scrape/database.json") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                1198490    1198510   1198550  \
# type                              game       game      game
# name          All That Remains: Part 1  Paperball  Moderium
# steam_appid                    1198490    1198510   1198550
# required_age                         0          0         0
# is_free                          False      False     False
#
#                            1198600               1198630  \
# type                          game                  game
# name          Pizza Time Explosion  Customer Cums First!
# steam_appid                1198600               1198630
# required_age                     0                     0
# is_free                      False                 False
#
#                                      1198700        1198730       1198740  \
# type                                    game           game          game
# name          Chained: A Victorian Nightmare  Hentai Police  Colony Siege
# ...

# %%
df1 = df.T
df1 = df1.head(10)
# Out:
#          type                      name steam_appid required_age is_free  \
# 1198490  game  All That Remains: Part 1     1198490            0   False
# 1198510  game                 Paperball     1198510            0   False
# 1198550  game                  Moderium     1198550            0   False
# 1198600  game      Pizza Time Explosion     1198600            0   False
# 1198630  game      Customer Cums First!     1198630            0   False
#
#                                       detailed_description  \
# 1198490  “Duncan Price is paranoid” they used to say. H...
# 1198510  It's time to get rolling!<br><br>Navigate tric...
# 1198550  Moderium is a Wave-Based Isometric Action Role...
# 1198600  <img src="https://cdn.akamai.steamstatic.com/s...
# 1198630  <img src="https://cdn.akamai.steamstatic.com/s...
#
#                                             about_the_game  \
# 1198490  “Duncan Price is paranoid” they used to say. H...
# ...

# %%
df1
# Out:
#          type                            name steam_appid required_age  \
# 1198490  game        All That Remains: Part 1     1198490            0
# 1198510  game                       Paperball     1198510            0
# 1198550  game                        Moderium     1198550            0
# 1198600  game            Pizza Time Explosion     1198600            0
# 1198630  game            Customer Cums First!     1198630            0
# 1198700  game  Chained: A Victorian Nightmare     1198700            0
# 1198730  game                   Hentai Police     1198730            0
# 1198740  game                    Colony Siege     1198740            0
# 1198810  game                   Wolf and Pigs     1198810            0
# 1198820  game             Monster Girl Garden     1198820            0
#
#         is_free                               detailed_description  \
# 1198490   False  “Duncan Price is paranoid” they used to say. H...
# ...

# %%
df1.to_csv('steam.csv')

# %%
df.isna().sum()
# Out:
# 1198490     9
# 1198510     5
# 1198550    10
# 1198600     6
# 1198630    10
#            ..
# 1113770     7
# 1113780     8
# 1113000     5
# 1113060     9
# 1113110     9
# Length: 4625, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, type to drm_notice
# Columns: 4625 entries, 1198490 to 1113110
# dtypes: object(4625)
# memory usage: 1.6+ MB

# %%
df1.columns
# Out:
# Index(['type', 'name', 'steam_appid', 'required_age', 'is_free',
#        'detailed_description', 'about_the_game', 'short_description',
#        'supported_languages', 'header_image', 'website', 'pc_requirements',
#        'mac_requirements', 'linux_requirements', 'legal_notice', 'developers',
#        'publishers', 'price_overview', 'packages', 'package_groups',
#        'platforms', 'categories', 'genres', 'screenshots', 'movies',
#        'release_date', 'support_info', 'background', 'content_descriptors',
#        'num_reviews', 'review_score', 'review_score_desc', 'total_positive',
#        'total_negative', 'total_reviews', 'controller_support', 'dlc', 'demos',
#        'recommendations', 'achievements', 'reviews', 'ext_user_account_notice',
#        'metacritic', 'drm_notice'],
#       dtype='object')

# %%
import pandas as pd
import sqlite3

#read the CSV
df = pd.read_csv('steam.csv')
#connect to a database
conn = sqlite3.connect("database.db") #if the db does not exist, this creates a database.db file in the current directory
#store your table in the database:
df.to_sql('Steam_games', conn)
#read a SQL Query out of your database and into a pandas dataframe
sql_string = 'SELECT * FROM Steam_games'
df = pd.read_sql(sql_string, conn)
